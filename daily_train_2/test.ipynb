# %%
from PIL import Image
import os

# %%
list_names = []

for filename in os.listdir('.'): 
    if '.png' in filename:
        fig_name = filename
        fig_name = fig_name.strip('.png')
        list_names.append(fig_name)

# %%
list_names
# Out:
# ['fig_3680',
#  'fig_3681',
#  'fig_3682',
#  'fig_3683',
#  'fig_3684',
#  'fig_3685',
#  'fig_3686',
#  'fig_3687',
#  'fig_3688',
#  'fig_3689',
#  'fig_3690',
#  'fig_3691',
#  'fig_3692',
#  'fig_3693',
#  'fig_3694',
#  'fig_3695',
#  'fig_3696',
#  'fig_3697',
#  'fig_3698',
#  'fig_3699',
#  'fig_3700',
#  'fig_3701',
#  'fig_3702',
#  'fig_3703',
#  'fig_3704',
#  'fig_3705',
#  'fig_3706',
#  'fig_3707',
#  'fig_3708',
#  'fig_3709',
#  'fig_3710',
#  'fig_3711',
#  'fig_3712',
#  'fig_3713',
#  'fig_3714',
#  'fig_3715',
#  'fig_3716',
#  'fig_3717',
#  'fig_3718',
#  'fig_3719',
#  'fig_3720',
#  'fig_3721',
#  'fig_3722',
#  'fig_3723',
#  'fig_3724',
#  'fig_3725',
#  'fig_3726',
#  'fig_3727',
#  'fig_3728',
#  'fig_3729',
#  'fig_3730',
#  'fig_3731',
#  'fig_3732',
#  'fig_3733',
#  'fig_3734',
#  'fig_3735',
#  'fig_3736',
#  'fig_3737',
#  'fig_3738',
#  'fig_3739',
#  'fig_3740',
#  'fig_3741',
#  'fig_3742',
#  'fig_3743',
#  'fig_3744',
#  'fig_3745',
# ...

# %%
def crop_img(fig_name): 
    img = Image.open(f'{fig_name}.png')
    crop_area = (75,100,625,340)
    cropped_img = img.crop(crop_area)
    new_name = f'cropped_images\\{fig_name}_cropped.png'
    cropped_img.save(new_name)

for name in list_names: 
    crop_img(name)
